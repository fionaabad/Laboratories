# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import bernoulli
from scipy.stats import binom
from scipy.stats import geom
from scipy.stats import poisson

from scipy.stats import uniform
from scipy.stats import expon
from scipy.stats import norm

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.29734099 2.33138048 2.00506569 2.84468972 2.34299189 2.18642309
#  2.96700572 2.53465968 2.32532851 2.27202842]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
import numpy as np
np.random.random(5)
# Out:
# array([0.4559077 , 0.75939677, 0.23948355, 0.99432991, 0.33634647])

# %%
from scipy.stats import uniform

def uni_dist(bottom, ceiling, count):
    x = np.random.random(count)
    return bottom + (ceiling-bottom)*x

# %%
import numpy as np

def generate_uniform_numbers(bottom, ceiling, count):
    return np.random.uniform(bottom, ceiling, count)

import matplotlib.pyplot as plt

# Generate 100 random numbers between 10 and 15
numbers1 = generate_uniform_numbers(10, 15, 100)

# Generate 1000 random numbers between 10 and 60
numbers2 = generate_uniform_numbers(10, 60, 1000)

# Plotting histogram for numbers1
plt.hist(numbers1, bins=10)
plt.xlabel('Value')
plt.ylabel('Count')
plt.title('Uniform Distribution')
plt.show()

# Plotting histogram for numbers2
plt.hist(numbers2, bins=10)
plt.xlabel('Value')
plt.ylabel('Count')
plt.title('Uniform Distribution')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# The more times we repeated the more closer we are to a uniform distibution

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def normal(mu, sigma):
    return norm(mu, sigma)

a = normal(10,1)
b = normal(10,50)

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_normal_numbers(mu, sigma, size):
    return np.random.normal(mu, sigma, size)

# Generating 1,000 normally distributed numbers with mean 10 and standard deviation 1
numbers_1 = generate_normal_numbers(10, 1, 1000)

# Generating 1,000 normally distributed numbers with mean 10 and standard deviation 50
numbers_2 = generate_normal_numbers(10, 50, 1000)

# Plotting the distributions
plt.figure(figsize=(10, 6))
plt.hist(numbers_1, bins=30, alpha=0.5, label='Mean=10, Std Dev=1')
plt.hist(numbers_2, bins=30, alpha=0.5, label='Mean=10, Std Dev=50')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Normal Distribution')
plt.legend()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# They have different standard deviations

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
df = pd.read_csv('vehicles.csv')
plt.hist(df['Fuel Barrels/Year'], bins = 20)
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plt.hist(df['CO2 Emission Grams/Mile'], bins = 20)
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
plt.hist(df['Combined MPG'], bins = 20)
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# All of them seem like a normal distribution, we should do a goodness of fit

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with a mean of 1 and 100 and a size of 1000.
#
# 1. Plot the distributions as histograms with the number of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exponential(mu, size):
    return np.random.exponential(scale= mu, size =size)

# mean is the same as lambda and we do the inverse

# %%
a = exponential(1, 1000)
b = exponential(100, 1000)

# %%
plt.hist(a, bins=100)
plt.show()

plt.hist(b, bins=100)
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# the mean/ variance/ expected values are different

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon

lambda_inv = 10
exp_distribution = expon(scale=lambda_inv)

p = exp_distribution.cdf(15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
1 - p
# Out:
# 0.2231301601484298
