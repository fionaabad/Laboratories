# %%
import pandas as pd

# %% [markdown]
# ## Exercise 1: Clean and Format the Data

# %%
df1 = pd.read_csv('file1 (1).txt')
df2 = pd.read_csv('file2.txt')
df3 = pd.read_csv('file3.txt')

# %%
def clean(df):
    df.columns = [col.replace(' ', '_').lower() for col in df.columns]
    
    def convert(cell):
        if str(cell) == 'nan':
            return 'nan'
        else:
            return float(cell.replace('%', ''))
    
    df['customer_lifetime_value'] = df['customer_lifetime_value'].apply(convert)
    df.gender = df.gender.replace('Male', 'M').replace('Femal', 'F').replace('female', 'F')
    df.customer_lifetime_value = df.customer_lifetime_value.astype(float)
    
    df = df.dropna(how='all')
    df.customer_lifetime_value.fillna(df.customer_lifetime_value.mean(), inplace=True)
    
    if df.duplicated().sum() == 0:
        pass
    
    return df
df1 = clean(df1)
df2= clean(df2)
# Out:
# C:\Users\Fiona A\AppData\Local\Temp\ipykernel_12292\1323797445.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.customer_lifetime_value.fillna(df.customer_lifetime_value.mean(), inplace=True)

# %%
df3.columns = [col.replace(' ', '_').lower() for col in df3.columns]
df3.gender = df3.gender.replace('Male', 'M').replace('Femal', 'F').replace('female', 'F')
df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
df1_sorted = df1.sort_values('customer')
df2_sorted = df2.sort_values('customer')
df3_sorted = df3.sort_values('customer')

# %%
merged_id = pd.merge(df1, pd.merge(df2,df3, on= 'customer', how= 'outer'), on= 'customer', how ='outer')
merged_id
# Out:
#      customer        st_x gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9051  LA72316         NaN    NaN                   NaN
# 9052  PK87824         NaN    NaN                   NaN
# 9053  TD14365         NaN    NaN                   NaN
# 9054  UP19263         NaN    NaN                   NaN
# 9055  Y167826         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                7.936903e+05      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %% [markdown]
# ## Exercise 2: Structuring Data

# %% [markdown]
# ### Exercise 1: Clean and Format the Data 1

# %%
import pandas as pd

# %%
mkt = pd.read_csv('marketing_customer_analysis.txt')

# %%
mkt.columns = [col.replace(' ', '_').lower() for col in mkt.columns]
mkt.sort_values('customer')
mkt = mkt.dropna(how='all')
mkt.drop_duplicates()
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
mkt['effective_to_date'] = pd.to_datetime(mkt['effective_to_date'])

# %%
import pandas as pd

mkt['effective_to_date'] = pd.to_datetime(mkt['effective_to_date'])

mkt['months'] = mkt['effective_to_date'].dt.month

mkt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed:_0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10279 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10279 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
mkt.to_csv('output.csv', index=False)  # to convert the file to a csv file.
# index = False is used to not store the values in the index column

# %% [markdown]
# ### Exercise 2: Structuring Data

# %%
mkt['total_revenue'] = (mkt.income) - (mkt.total_claim_amount)

# %%
import pandas as pd

# Ordenar el DataFrame según la suma de 'C' agrupado por 'A'
sorted_mkt = mkt.groupby('sales_channel')['total_revenue'].sum().reset_index().sort_values(by='total_revenue', ascending=False)
sorted_mkt
# Out:
#   sales_channel  total_revenue
# 0         Agent   1.506799e+08
# 1        Branch   1.124744e+08
# 2   Call Center   8.012840e+07
# 3           Web   6.149350e+07

# %%
women = (mkt['gender'] == 'F')
mean_women = mkt[women].mean()

men = (mkt['gender'] == 'M')
mean_men = mkt[men].mean()
# Out:
# C:\Users\Fiona A\AppData\Local\Temp\ipykernel_12292\3667932688.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   mean_women = mkt[women].mean()
# C:\Users\Fiona A\AppData\Local\Temp\ipykernel_12292\3667932688.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_women = mkt[women].mean()
# C:\Users\Fiona A\AppData\Local\Temp\ipykernel_12292\3667932688.py:5: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   mean_men = mkt[men].mean()
# ...

# %%
average_clv_mkt = mkt.groupby(['gender', 'education'])['customer_lifetime_value'].mean().reset_index()
average_clv_mkt
# Out:
#   gender             education  customer_lifetime_value
# 0      F              Bachelor              7874.269478
# 1      F               College              7748.823325
# 2      F                Doctor              7328.508916
# 3      F  High School or Below              8675.220201
# 4      F                Master              8157.053154
# 5      M              Bachelor              7703.601675
# 6      M               College              8052.459288
# 7      M                Doctor              7415.333638
# 8      M  High School or Below              8149.687783
# 9      M                Master              8168.832659

# %%
highest_complains = mkt.groupby(['months', 'policy_type'])['total_claim_amount'].count().reset_index().sort_values(by='total_claim_amount', ascending= False)
highest_complains
# Out:
#    months     policy_type  total_claim_amount
# 1       1   Personal Auto                4329
# 4       2   Personal Auto                3799
# 0       1  Corporate Auto                1252
# 3       2  Corporate Auto                1089
# 2       1    Special Auto                 237
# 5       2    Special Auto                 204
