# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
import datetime 

SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from stackapi import StackAPI
#       2 import datetime
#       4 SITE = StackAPI('stackoverflow')
#
# ModuleNotFoundError: No module named 'stackapi'

# %%
# transformar data en tiempo

fecha = datetime.datetime(2023, 6, 1)  # la fecha que quieres convertir a timestamp
timestamp = fecha.timestamp()
print(int(timestamp))
print(fecha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # transformar data en tiempo
# ----> 3 fecha = datetime.datetime(2023, 6, 1)  # la fecha que quieres convertir a timestamp
#       4 timestamp = fecha.timestamp()
#       5 print(int(timestamp))
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
import datetime

date_string = "2023-07-03"
date = datetime.datetime.strptime(date_string, "%Y-%m-%d")
timestamp = datetime.datetime.timestamp(date)

dic = {'post_id': [], 'comment_id': []}

for item in comments.get('items'):
    if item.get('creation_date') >= timestamp:
        dic['post_id'].append(item.get('post_id'))
        dic['comment_id'].append(item.get('comment_id'))

print(dic)
# Out:
# {'post_id': [76836228, 76784905, 76835803, 76836263, 76836288, 76836299, 66191256, 76829227, 76830015, 76836278, 76833931, 76786893, 76836197, 11670441, 76836220, 76835879, 76836121, 76836212, 76383255, 76812647, 76836210, 76836299, 76834286, 76835907, 76835989, 76836096, 76836117, 76836266, 76830640, 76835803, 76836238, 76835696, 76834047, 76836268, 76827831, 76832629, 76833182, 32851777, 76836176, 76836197, 76834374, 76836260, 76835657, 76829909, 76836021, 76836291, 76836282, 76834026, 76836216, 76835777, 76836278, 76830550, 76759153, 76836218, 69933874, 75875812, 76835974, 76836266, 76828604, 76835803, 76833924, 39172305, 76832190, 76830416, 76835777, 76831583, 76836273, 76836132, 76836200, 76836197, 76836278, 76808289, 76835905, 76836261, 48411543, 76836260, 76836266, 76836071, 76829040, 76836205, 8905549, 76805971, 76835989, 76821739, 76830049, 68386282, 76830612, 76835989, 76836200, 76836112, 76836202, 76836260, 76835987, 76836248, 76806212, 76836261, 76836197, 76835822, 76836097, 74241537, 76813252, 76835453, 76830550, 76832846, 58205920, 76836248, 76836248, 76836248, 76671787, 76830640, 76831049, 76836248, 76835277, 76835996, 76820152, 76836096, 76836208, 76827062, 76826826, 45760843, 76835983, 76832991, 76836096, 76836121, 76835664, 76828286, 76836248, 76836096, 76835907, 76835907, 76836189, 76832626, 76835974, 76836218, 76834695, 76832968, 76836222, 76798810, 76813529, 63665339, 76835818, 76836132, 76751677, 76828286, 76833660, 44729052, 76835853, 76835125, 60615030, 76836099, 76836206, 76836145, 76836200, 76833924, 76836200, 76834810, 76833662, 76835962, 74463334, 76835497, 76835734, 76835039, 76836209, 58615772, 76836090, 76835983, 76836144, 76831961, 76834830, 76836049, 76836124, 76830368, 76835310, 76836176, 76641965, 76834892, 73038852, 76785630, 76834392, 76835933, 76835157, 76836020, 76811715, 76806395, 76836124, 76835933, 76835918, 76801620, 76835867, 62349560, 76835915, 76835577, 76835863, 76836096, 76830036, 76835299, 76836177, 76833232, 76836175, 76816293, 76832807, 76835933, 76836124, 76836192, 76835728, 76835974, 76835982, 76834012, 76836181, 76834705, 76833341, 76836033, 76836132, 76836149, 18730859, 76836124, 76829884, 76835803, 57140286, 76836149, 76832807, 76830782, 76835502, 76835858, 60263935, 76835933, 76835604, 76835179, 76836175, 76834983, 76834987, 76836096, 76809880, 76836023, 76834695, 76836013, 76832807, 76836052, 76836038, 76835958, 76793125, 76835853, 76761298, 76835946, 76834012, 76835983, 76836144, 76829630, 76835270, 76835873, 76832276, 66376666, 76835674, 76835604, 76834185, 76834123, 76835346, 52913040, 76836052, 76835853, 76835931, 76833560, 76836050, 76833997, 70900148, 76808289, 76788594, 76836132, 76834440, 76829586, 76835346, 76824696, 76833997, 76835672, 76836071, 55985294, 76836072, 76836118, 76830125, 58652141, 76835369, 76835963, 76821268, 69043397, 76835986, 76832092, 76829819, 76809300, 76833235, 76835689, 76834723, 76836023, 76835986, 76829576, 76833610, 76833836, 76791597, 76836112, 76815594, 76835962, 76832406, 76835925, 76763918, 76833873, 76836112, 76835502, 76820910, 76833874, 76833931, 76834169, 76835962, 76836013, 76835843, 38294075, 76835986, 76428060, 76835999, 76831198, 76789809, 76835482, 76834392, 76831688, 76833711, 76835841, 76804208, 76834817, 55128956, 76835999, 76815520, 76832781, 76659405, 76803762, 76835689, 76830709, 76829615, 76834948, 76836063, 70556156, 76835745, 76749346, 76835853, 75694572, 76828286, 76828751, 56055323, 76835983, 76831198, 25286438, 76836072, 76828124, 76834585, 76835907, 76834522, 76835546, 76835918, 76816143, 76836045, 76835982, 76833232, 76835986, 76836072, 75028147, 76835920, 76835842, 76836017, 76835915, 5677558, 76204472, 59111644, 76835346, 76835960, 76835101, 76835853, 76835983, 76811899, 76835761, 76823467, 76826086, 76835905, 76617514, 76835960, 76831582, 76835634, 76835473, 76835842, 76828782, 59407819, 76829012, 76835273, 39252620, 76835829, 76835875, 76835513, 76835445, 76835614, 76834660, 76833338, 76835982, 76835778, ...

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')

date_string = "2023-07-03"
date = datetime.datetime.strptime(date_string, "%Y-%m-%d")
timestamp = datetime.datetime.timestamp(date)

questions = SITE.fetch('questions', sort='votes')

'''
for quest in questions['items']:
    if item.get('creation_date') >= timestamp:
        if 'title' not in quest or quest['is_answered'] == False:
            continue
        title = quest['title']
        print('Question :- {0}'.format(title))
        question_id = quest['question_id']
        print('Question ID :- {0}'.format(question_id))
        top_answer = SITE.fetch('questions/' + str(question_id) + '/answers', order = 'desc', sort='votes')
        print('Most Voted Answer ID :- {0}'.format(top_answer['items'][0]['answer_id']))
        
'''
# Out:
# Question :- Why is processing a sorted array faster than processing an unsorted array?
# Question ID :- 11227809
# Most Voted Answer ID :- 11227902
# Question :- How do I undo the most recent local commits in Git?
# Question ID :- 927358
# Most Voted Answer ID :- 927386
# Question :- How do I delete a Git branch locally and remotely?
# Question ID :- 2003505
# Most Voted Answer ID :- 2003515
# Question :- What is the difference between &#39;git pull&#39; and &#39;git fetch&#39;?
# Question ID :- 292357
# Most Voted Answer ID :- 292359
# Question :- What does the &quot;yield&quot; keyword do in Python?
# Question ID :- 231767
# Most Voted Answer ID :- 231855
# Question :- How can I remove a specific item from an array in JavaScript?
# Question ID :- 5767325
# Most Voted Answer ID :- 5767357
# Question :- Which JSON content type do I use?
# Question ID :- 477816
# Most Voted Answer ID :- 477819
# Question :- How do I rename a local Git branch?
# Question ID :- 6591213
# Most Voted Answer ID :- 6591218
# Question :- How do I undo &#39;git add&#39; before commit?
# Question ID :- 348170
# Most Voted Answer ID :- 348234
# Question :- What is the &#39;--&gt;&#39; operator in C/C++?
# Question ID :- 1642028
# Most Voted Answer ID :- 1642035
# Question :- Can comments be used in JSON?
# Question ID :- 244777
# Most Voted Answer ID :- 244858
# Question :- How do I force &quot;git pull&quot; to overwrite local files?
# Question ID :- 1125968
# Most Voted Answer ID :- 8888015
# Question :- What and where are the stack and heap?
# Question ID :- 79923
# Most Voted Answer ID :- 80113
# Question :- Why does HTML think “chucknorris” is a color?
# Question ID :- 8318911
# Most Voted Answer ID :- 8333464
# Question :- How do I check if an element is hidden in jQuery?
# Question ID :- 178325
# Most Voted Answer ID :- 178450
# Question :- How do I check out a remote Git branch?
# Question ID :- 1783405
# Most Voted Answer ID :- 1783426
# Question :- What does &quot;use strict&quot; do in JavaScript, and what is the reasoning behind it?
# Question ID :- 1335851
# Most Voted Answer ID :- 1335881
# Question :- What does if __name__ == &quot;__main__&quot;: do?
# Question ID :- 419163
# Most Voted Answer ID :- 419185
# Question :- How do I remove local (untracked) files from the current Git working tree?
# Question ID :- 61212
# Most Voted Answer ID :- 64966
# Question :- How do I make Git forget about a file that was tracked, but is now in .gitignore?
# Question ID :- 1274057
# Most Voted Answer ID :- 1274447
# Question :- Does Python have a ternary conditional operator?
# Question ID :- 394809
# Most Voted Answer ID :- 394814
# Question :- Is Java &quot;pass-by-reference&quot; or &quot;pass-by-value&quot;?
# Question ID :- 40480
# Most Voted Answer ID :- 40523
# Question :- How do I redirect to another webpage?
# Question ID :- 503093
# Most Voted Answer ID :- 506004
# Question :- How to modify existing, unpushed commit messages?
# Question ID :- 179123
# Most Voted Answer ID :- 179147
# Question :- How do JavaScript closures work?
# Question ID :- 111102
# Most Voted Answer ID :- 111111
# Question :- How do I revert a Git repository to a previous commit?
# Question ID :- 4114095
# Most Voted Answer ID :- 4114122
# Question :- var functionName = function() {} vs function functionName() {}
# Question ID :- 336859
# Most Voted Answer ID :- 336868
# Question :- Why is subtracting these two epoch-milli Times (in year 1927) giving a strange result?
# Question ID :- 6841333
# Most Voted Answer ID :- 6841479
# Question :- What is the difference between String and string in C#?
# Question ID :- 7074
# Most Voted Answer ID :- 7077
# Question :- How to check whether a string contains a substring in JavaScript?
# Question ID :- 1789945
# Most Voted Answer ID :- 1789952
# Question :- How do I remove a property from a JavaScript object?
# Question ID :- 208105
# Most Voted Answer ID :- 208106
# Question :- How to find all files containing specific text (string) on Linux?
# Question ID :- 16956810
# Most Voted Answer ID :- 16957078
# Question :- What are metaclasses in Python?
# Question ID :- 100003
# Most Voted Answer ID :- 6581949
# Question :- How do I check whether a file exists without exceptions?
# Question ID :- 82831
# Most Voted Answer ID :- 82852
# Question :- How do I merge two dictionaries in a single expression in Python?
# Question ID :- 38987
# Most Voted Answer ID :- 26853961
# Question :- How do I return the response from an asynchronous call?
# Question ID :- 14220321
# Most Voted Answer ID :- 14220323
# Question :- Move the most recent commit(s) to a new branch with Git
# Question ID :- 1628563
# Most Voted Answer ID :- 1628584
# Question :- What is the difference between px, dip, dp, and sp?
# Question ID :- 2025282
# Most Voted Answer ID :- 2025541
# Question :- What is the difference between POST and PUT in HTTP?
# Question ID :- 630453
# Most Voted Answer ID :- 630475
# Question :- How do I include a JavaScript file in another JavaScript file?
# Question ID :- 950087
# Most Voted Answer ID :- 950146
# Question :- What is the difference between &quot;let&quot; and &quot;var&quot;?
# Question ID :- 762011
# Most Voted Answer ID :- 11444416
# Question :- How do I discard unstaged changes in Git?
# Question ID :- 52704
# Most Voted Answer ID :- 52713
# Question :- How do I get the directory where a Bash script is located from within the script itself?
# Question ID :- 59895
# Most Voted Answer ID :- 246128
# Question :- How to disable text selection highlighting
# Question ID :- 826782
# Most Voted Answer ID :- 4407335
# Question :- How do I change the URI (URL) for a remote Git repository?
# Question ID :- 2432764
# Most Voted Answer ID :- 2432799
# Question :- How do I execute a program or call a system command?
# Question ID :- 89228
# Most Voted Answer ID :- 89243
# Question :- Which equals operator (== vs ===) should be used in JavaScript comparisons?
# Question ID :- 359494
# Most Voted Answer ID :- 359509
# Question :- What is the maximum length of a URL in different browsers?
# Question ID :- 417142

# %%
'''
import datetime

questions = SITE.fetch('questions')

date_string = "2023-07-03"
date = datetime.datetime.strptime(date_string, "%Y-%m-%d")
timestamp = datetime.datetime.timestamp(date)



for item in questions.get('items'):
    if item.get('creation_date') >= timestamp:
        print(item['title'])

'''
# Out:
# '\nimport datetime\n\nquestions = SITE.fetch(\'questions\')\n\ndate_string = "2023-07-03"\ndate = datetime.datetime.strptime(date_string, "%Y-%m-%d")\ntimestamp = datetime.datetime.timestamp(date)\n\n\n\nfor item in questions.get(\'items\'):\n    if item.get(\'creation_date\') >= timestamp:\n        print(item[\'title\'])\n\n'

# %%
import datetime

answers = SITE.fetch('answers')

date_string = "2023-07-03"
date = datetime.datetime.strptime(date_string, "%Y-%m-%d")
timestamp = datetime.datetime.timestamp(date)

'''
for item in answers.get('items'):
    if item.get('creation_date') >= timestamp:
        print(item['title'])
'''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 13
#      11 for item in answers.get('items'):
#      12     if item.get('creation_date') >= timestamp:
# ---> 13         print(item['title'])
#
# KeyError: 'title'

# %%
date_string = "2023-07-3"
date = datetime.datetime.strptime(date_string, "%Y-%m-%d")
timestamp = datetime.datetime.timestamp(date)

print(timestamp)
# Out:
# 1688335200.0

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
import datetime

date_string = "2023-08-04"
date = datetime.datetime.strptime(date_string, "%Y-%m-%d")
timestamp = datetime.datetime.timestamp(date)

questions = SITE.fetch('questions', sort='votes')

questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 222,
#  'total': 0,
#  'items': [{'tags': ['java',
#     'c++',
#     'performance',
#     'cpu-architecture',
#     'branch-prediction'],
#    'owner': {'reputation': 493767,
#     'user_id': 87234,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/FkjBe.png?s=256&g=1',
#     'display_name': 'GManNickG',
#     'link': 'https://stackoverflow.com/users/87234/gmannickg'},
#    'is_answered': True,
#    'view_count': 1827255,
#    'protected_date': 1399067470,
#    'accepted_answer_id': 11227902,
#    'answer_count': 25,
#    'score': 27053,
#    'last_activity_date': 1685434992,
#    'creation_date': 1340805096,
#    'last_edit_date': 1683824982,
#    'question_id': 11227809,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/11227809/why-is-processing-a-sorted-array-faster-than-processing-an-unsorted-array',
#    'title': 'Why is processing a sorted array faster than processing an unsorted array?'},
#   {'tags': ['git', 'version-control', 'repository', 'git-commit', 'undo'],
#    'owner': {'reputation': 48987,
#     'user_id': 89904,
#     'user_type': 'registered',
#     'accept_rate': 65,
#     'profile_image': 'https://www.gravatar.com/avatar/4fef65cead13e5d519f6bce3c501a537?s=256&d=identicon&r=PG',
#     'display_name': 'Hamza Yerlikaya',
#     'link': 'https://stackoverflow.com/users/89904/hamza-yerlikaya'},
#    'is_answered': True,
#    'view_count': 12991806,
#    'protected_date': 1370840488,
#    'accepted_answer_id': 927386,
#    'answer_count': 105,
#    'community_owned_date': 1363428511,
#    'score': 25791,
#    'last_activity_date': 1688664813,
#    'creation_date': 1243620554,
#    'last_edit_date': 1684875588,
#    'question_id': 927358,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/927358/how-do-i-undo-the-most-recent-local-commits-in-git',
#    'title': 'How do I undo the most recent local commits in Git?'},
#   {'tags': ['git', 'version-control', 'git-branch', 'git-push', 'git-remote'],
#    'owner': {'reputation': 456279,
#     'user_id': 95592,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://i.stack.imgur.com/uMfjc.jpg?s=256&g=1',
#     'display_name': 'Matthew Rankin',
#     'link': 'https://stackoverflow.com/users/95592/matthew-rankin'},
#    'is_answered': True,
#    'view_count': 11077977,
#    'protected_date': 1358718496,
#    'accepted_answer_id': 2003515,
#    'answer_count': 44,
#    'score': 20224,
#    'last_activity_date': 1689954195,
#    'creation_date': 1262653935,
#    'last_edit_date': 1672782568,
#    'question_id': 2003505,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/2003505/how-do-i-delete-a-git-branch-locally-and-remotely',
#    'title': 'How do I delete a Git branch locally and remotely?'},
#   {'tags': ['git', 'version-control', 'git-pull', 'git-fetch'],
#    'owner': {'reputation': 278925,
#     'user_id': 6068,
#     'user_type': 'registered',
#     'accept_rate': 65,
#     'profile_image': 'https://www.gravatar.com/avatar/931970b8dc51b72e05e3a12b88612d61?s=256&d=identicon&r=PG',
#     'display_name': 'Pablo Fernandez',
#     'link': 'https://stackoverflow.com/users/6068/pablo-fernandez'},
#    'is_answered': True,
#    'view_count': 3389635,
#    'protected_date': 1362879044,
#    'accepted_answer_id': 292359,
#    'answer_count': 38,
#    'score': 13661,
#    'last_activity_date': 1685436089,
#    'creation_date': 1226742669,
#    'last_edit_date': 1658169844,
#    'question_id': 292357,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/292357/what-is-the-difference-between-git-pull-and-git-fetch',
#    'title': 'What is the difference between &#39;git pull&#39; and &#39;git fetch&#39;?'},
#   {'tags': ['python', 'iterator', 'generator', 'yield'],
#    'owner': {'reputation': 143050,
#     'user_id': 18300,
#     'user_type': 'registered',
#     'accept_rate': 92,
#     'profile_image': 'https://i.stack.imgur.com/jcyI4.jpg?s=256&g=1',
#     'display_name': 'Alex. S.',
#     'link': 'https://stackoverflow.com/users/18300/alex-s'},
#    'is_answered': True,
#    'view_count': 3228494,
#    'protected_date': 1360547307,
#    'accepted_answer_id': 231855,
#    'answer_count': 52,
#    'score': 12687,
#    'last_activity_date': 1690141101,
#    'creation_date': 1224800471,
#    'last_edit_date': 1687352014,
#    'question_id': 231767,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/231767/what-does-the-yield-keyword-do-in-python',
#    'title': 'What does the &quot;yield&quot; keyword do in Python?'},
#   {'tags': ['javascript', 'arrays'],
#    'owner': {'reputation': 128107,
#     'user_id': 364969,
#     'user_type': 'registered',
#     'accept_rate': 86,
#     'profile_image': 'https://www.gravatar.com/avatar/79e7cefc9e7deb0e0bf422baa1a38a2c?s=256&d=identicon&r=PG',
#     'display_name': 'Walker',
#     'link': 'https://stackoverflow.com/users/364969/walker'},
#    'is_answered': True,
#    'view_count': 11870534,
#    'protected_date': 1418673600,
#    'accepted_answer_id': 5767357,
#    'answer_count': 150,
#    'score': 11582,
#    'last_activity_date': 1691146639,
#    'creation_date': 1303597038,
#    'last_edit_date': 1675693432,
#    'question_id': 5767325,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/5767325/how-can-i-remove-a-specific-item-from-an-array-in-javascript',
#    'title': 'How can I remove a specific item from an array in JavaScript?'},
#   {'tags': ['json', 'mime-types', 'content-type'],
#    'owner': {'reputation': 235392,
#     'user_id': 12870,
#     'user_type': 'registered',
#     'accept_rate': 63,
#     'profile_image': 'https://www.gravatar.com/avatar/f0af40756420859b5b63cbceb6d30505?s=256&d=identicon&r=PG',
#     'display_name': 'Oli',
#     'link': 'https://stackoverflow.com/users/12870/oli'},
#    'is_answered': True,
#    'view_count': 3788751,
#    'protected_date': 1435276338,
#    'accepted_answer_id': 477819,
#    'answer_count': 39,
#    'score': 11450,
#    'last_activity_date': 1690617813,
#    'creation_date': 1232897119,
#    'last_edit_date': 1661768573,
#    'question_id': 477816,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/477816/which-json-content-type-do-i-use',
#    'title': 'Which JSON content type do I use?'},
#   {'tags': ['git', 'version-control', 'git-branch'],
#    'owner': {'reputation': 122413,
#     'user_id': 338204,
#     'user_type': 'registered',
#     'accept_rate': 44,
#     'profile_image': 'https://www.gravatar.com/avatar/c145a12cd17d3b3ffff033681a694abe?s=256&d=identicon&r=PG',
#     'display_name': 'Forrest',
#     'link': 'https://stackoverflow.com/users/338204/forrest'},
#    'is_answered': True,
#    'view_count': 5095668,
#    'protected_date': 1498428177,
#    'accepted_answer_id': 6591218,
#    'answer_count': 40,
#    'score': 11330,
#    'last_activity_date': 1679637166,
#    'creation_date': 1309922436,
#    'last_edit_date': 1658721109,
#    'question_id': 6591213,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/6591213/how-do-i-rename-a-local-git-branch',
#    'title': 'How do I rename a local Git branch?'},
#   {'tags': ['git', 'undo', 'git-add'],
#    'owner': {'reputation': 152957,
#     'user_id': 14069,
#     'user_type': 'registered',
#     'accept_rate': 72,
#     'profile_image': 'https://www.gravatar.com/avatar/0c29cc6ee1c170810ee1fd36fa7c2f95?s=256&d=identicon&r=PG',
#     'display_name': 'oz10',
#     'link': 'https://stackoverflow.com/users/14069/oz10'},
#    'is_answered': True,
#    'view_count': 5184499,
#    'protected_date': 1359649207,
#    'accepted_answer_id': 348234,
#    'answer_count': 38,
#    'score': 11128,
#    'last_activity_date': 1675280373,
#    'creation_date': 1228687066,
#    'last_edit_date': 1658714861,
#    'question_id': 348170,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/348170/how-do-i-undo-git-add-before-commit',
#    'title': 'How do I undo &#39;git add&#39; before commit?'},
#   {'tags': ['c++',
#     'c',
#     'operators',
#     'code-formatting',
#     'standards-compliance'],
#    'owner': {'reputation': 493767,
#     'user_id': 87234,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/FkjBe.png?s=256&g=1',
#     'display_name': 'GManNickG',
#     'link': 'https://stackoverflow.com/users/87234/gmannickg'},
#    'is_answered': True,
#    'view_count': 982651,
#    'protected_date': 1297320482,
#    'accepted_answer_id': 1642035,
#    'answer_count': 28,
#    'community_owned_date': 1262233068,
#    'score': 10054,
#    'last_activity_date': 1690695581,
#    'creation_date': 1256799465,
#    'last_edit_date': 1680185464,
#    'question_id': 1642028,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/1642028/what-is-the-operator-in-c-c',
#    'title': 'What is the &#39;--&gt;&#39; operator in C/C++?'},
#   {'tags': ['json', 'comments'],
#    'owner': {'reputation': 106415,
#     'user_id': 4105,
#     'user_type': 'registered',
#     'accept_rate': 67,
#     'profile_image': 'https://www.gravatar.com/avatar/b478ef877842b1da9cdead7848572372?s=256&d=identicon&r=PG',
#     'display_name': 'Michael Gundlach',
#     'link': 'https://stackoverflow.com/users/4105/michael-gundlach'},
#    'is_answered': True,
#    'view_count': 3446427,
#    'protected_date': 1504847411,
#    'accepted_answer_id': 244858,
#    'answer_count': 59,
#    'score': 9397,
#    'last_activity_date': 1683414003,
#    'creation_date': 1225226343,
#    'last_edit_date': 1656981358,
#    'question_id': 244777,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/244777/can-comments-be-used-in-json',
#    'title': 'Can comments be used in JSON?'},
#   {'tags': ['git', 'version-control', 'overwrite', 'git-pull', 'git-fetch'],
#    'owner': {'reputation': 98987,
#     'user_id': 98046,
#     'user_type': 'registered',
#     'accept_rate': 69,
#     'profile_image': 'https://i.stack.imgur.com/i1oB2.jpg?s=256&g=1',
#     'display_name': 'Jakub Troszok',
#     'link': 'https://stackoverflow.com/users/98046/jakub-troszok'},
#    'is_answered': True,
#    'view_count': 7867741,
#    'protected_date': 1380552735,
#    'accepted_answer_id': 8888015,
#    'answer_count': 52,
#    'score': 9387,
#    'last_activity_date': 1683127185,
#    'creation_date': 1247583495,
#    'last_edit_date': 1658169728,
#    'question_id': 1125968,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/1125968/how-do-i-force-git-pull-to-overwrite-local-files',
#    'title': 'How do I force &quot;git pull&quot; to overwrite local files?'},
#   {'tags': ['data-structures',
#     'memory-management',
#     'stack',
#     'heap-memory',
#     'dynamic-memory-allocation'],
#    'owner': {'reputation': 92973,
#     'user_id': 13161,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/e3dcbde38b1f70c77b1db642f31a223d?s=256&d=identicon&r=PG',
#     'display_name': 'mattshane',
#     'link': 'https://stackoverflow.com/users/13161/mattshane'},
#    'is_answered': True,
#    'view_count': 1864053,
#    'protected_date': 1315942395,
#    'accepted_answer_id': 80113,
#    'answer_count': 31,
#    'score': 9292,
#    'last_activity_date': 1688825938,
#    'creation_date': 1221625086,
#    'last_edit_date': 1688825938,
#    'question_id': 79923,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/79923/what-and-where-are-the-stack-and-heap',
#    'title': 'What and where are the stack and heap?'},
#   {'tags': ['html', 'browser', 'background-color'],
#    'owner': {'reputation': 86357,
#     'user_id': 456584,
#     'user_type': 'registered',
#     'accept_rate': 88,
#     'profile_image': 'https://i.stack.imgur.com/uoYDJ.png?s=256&g=1',
#     'display_name': 'user456584',
#     'link': 'https://stackoverflow.com/users/456584/user456584'},
#    'is_answered': True,
#    'view_count': 739897,
#    'protected_date': 1360160534,
#    'accepted_answer_id': 8333464,
#    'answer_count': 9,
#    'score': 8674,
#    'last_activity_date': 1677062144,
#    'creation_date': 1322607262,
#    'last_edit_date': 1654501047,
#    'question_id': 8318911,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/8318911/why-does-html-think-chucknorris-is-a-color',
#    'title': 'Why does HTML think “chucknorris” is a color?'},
#   {'tags': ['javascript', 'jquery', 'dom', 'visibility'],
#    'owner': {'reputation': 129633,
#     'user_id': 21709,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/3ea9c684a2db319df788cecc6c98f9cd?s=256&d=identicon&r=PG',
#     'display_name': 'Philip Morton',
#     'link': 'https://stackoverflow.com/users/21709/philip-morton'},
#    'is_answered': True,
#    'view_count': 3139648,
#    'protected_date': 1578133711,
#    'accepted_answer_id': 178450,
#    'answer_count': 65,
#    'score': 8609,
#    'last_activity_date': 1687540960,
#    'creation_date': 1223384598,
#    'last_edit_date': 1657006199,
#    'question_id': 178325,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/178325/how-do-i-check-if-an-element-is-hidden-in-jquery',
#    'title': 'How do I check if an element is hidden in jQuery?'},
#   {'tags': ['git', 'git-checkout', 'remote-branch'],
#    'owner': {'reputation': 87953,
#     'user_id': 179467,
#     'user_type': 'registered',
#     'accept_rate': 87,
#     'profile_image': 'https://www.gravatar.com/avatar/e736f7016a80c3807e7cace569024ab8?s=256&d=identicon&r=PG',
#     'display_name': 'Juri Glass',
#     'link': 'https://stackoverflow.com/users/179467/juri-glass'},
#    'is_answered': True,
#    'view_count': 8077561,
#    'protected_date': 1368094052,
#    'accepted_answer_id': 1783426,
#    'answer_count': 43,
#    'score': 8446,
#    'last_activity_date': 1690528463,
#    'creation_date': 1258986226,
#    'last_edit_date': 1658169950,
#    'question_id': 1783405,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/1783405/how-do-i-check-out-a-remote-git-branch',
#    'title': 'How do I check out a remote Git branch?'},
#   {'tags': ['javascript', 'syntax', 'jslint', 'use-strict'],
#    'owner': {'reputation': 96397,
#     'user_id': 25847,
#     'user_type': 'registered',
#     'accept_rate': 82,
#     'profile_image': 'https://www.gravatar.com/avatar/34d142b034e7b194fc1708f3b20d9568?s=256&d=identicon&r=PG',
#     'display_name': 'Mark Rogers',
#     'link': 'https://stackoverflow.com/users/25847/mark-rogers'},
#    'is_answered': True,
#    'view_count': 1207152,
#    'protected_date': 1370840538,
#    'accepted_answer_id': 1335881,
#    'answer_count': 31,
#    'score': 8413,
#    'last_activity_date': 1686506881,
#    'creation_date': 1251303013,
#    'last_edit_date': 1657029561,
#    'question_id': 1335851,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/1335851/what-does-use-strict-do-in-javascript-and-what-is-the-reasoning-behind-it',
#    'title': 'What does &quot;use strict&quot; do in JavaScript, and what is the reasoning behind it?'},
#   {'tags': ['python',
#     'namespaces',
#     'program-entry-point',
#     'python-module',
#     'idioms'],
#    'owner': {'reputation': 177325,
#     'user_id': 51518,
#     'user_type': 'registered',
#     'accept_rate': 86,
#     'profile_image': 'https://www.gravatar.com/avatar/eb5a95cb1be342c4089183cd8232a7f2?s=256&d=identicon&r=PG',
#     'display_name': 'Devoted',
#     'link': 'https://stackoverflow.com/users/51518/devoted'},
#    'is_answered': True,
#    'view_count': 4450660,
#    'protected_date': 1365246276,
#    'accepted_answer_id': 419185,
#    'answer_count': 46,
#    'score': 8045,
#    'last_activity_date': 1688632322,
#    'creation_date': 1231301460,
#    'last_edit_date': 1668391615,
#    'question_id': 419163,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/419163/what-does-if-name-main-do',
#    'title': 'What does if __name__ == &quot;__main__&quot;: do?'},
#   {'tags': ['git', 'branch', 'git-branch'],
#    'owner': {'reputation': 342784,
#     'user_id': 4883,
#     'user_type': 'registered',
#     'accept_rate': 82,
#     'profile_image': 'https://www.gravatar.com/avatar/a92525f049e20db8f4ce3d62f3f0bb2b?s=256&d=identicon&r=PG',
#     'display_name': 'readonly',
#     'link': 'https://stackoverflow.com/users/4883/readonly'},
#    'is_answered': True,
#    'view_count': 3055873,
#    'accepted_answer_id': 64966,
#    'answer_count': 41,
#    'score': 7996,
#    'last_activity_date': 1665548284,
#    'creation_date': 1221383170,
#    'last_edit_date': 1659502707,
#    'question_id': 61212,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61212/how-do-i-remove-local-untracked-files-from-the-current-git-working-tree',
#    'title': 'How do I remove local (untracked) files from the current Git working tree?'},
#   {'tags': ['git', 'gitignore', 'git-rm'],
#    'owner': {'reputation': 97129,
#     'user_id': 16957,
#     'user_type': 'registered',
#     'accept_rate': 69,
#     'profile_image': 'https://www.gravatar.com/avatar/c5380b957ff8ce5cb14cf2282ffeb720?s=256&d=identicon&r=PG',
#     'display_name': 'Ivan',
#     'link': 'https://stackoverflow.com/users/16957/ivan'},
#    'is_answered': True,
#    'view_count': 2194432,
#    'protected_date': 1504805794,
#    'accepted_answer_id': 1274447,
#    'answer_count': 33,
#    'score': 7917,
#    'last_activity_date': 1683730174,
#    'creation_date': 1250191402,
#    'last_edit_date': 1658719875,
#    'question_id': 1274057,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/1274057/how-do-i-make-git-forget-about-a-file-that-was-tracked-but-is-now-in-gitignore',
#    'title': 'How do I make Git forget about a file that was tracked, but is now in .gitignore?'},
#   {'tags': ['python', 'operators', 'conditional-operator'],
#    'owner': {'reputation': 177325,
#     'user_id': 51518,
#     'user_type': 'registered',
#     'accept_rate': 86,
#     'profile_image': 'https://www.gravatar.com/avatar/eb5a95cb1be342c4089183cd8232a7f2?s=256&d=identicon&r=PG',
#     'display_name': 'Devoted',
#     'link': 'https://stackoverflow.com/users/51518/devoted'},
#    'is_answered': True,
#    'view_count': 2794477,
#    'protected_date': 1370841342,
#    'accepted_answer_id': 394814,
#    'answer_count': 32,
#    'score': 7764,
#    'last_activity_date': 1685989562,
#    'creation_date': 1230366738,
#    'last_edit_date': 1654483962,
#    'question_id': 394809,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/394809/does-python-have-a-ternary-conditional-operator',
#    'title': 'Does Python have a ternary conditional operator?'},
#   {'tags': ['java',
#     'methods',
#     'parameter-passing',
#     'pass-by-reference',
#     'pass-by-value'],
#    'owner': {'reputation': 4775,
#     'user_id': 4315,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/?s=256&d=identicon&r=PG',
#     'display_name': 'user4315',
#     'link': 'https://stackoverflow.com/users/4315/user4315'},
#    'is_answered': True,
#    'view_count': 2626705,
#    'protected_date': 1308938923,
#    'answer_count': 91,
#    'community_owned_date': 1347646975,
#    'score': 7709,
#    'last_activity_date': 1690495083,
#    'creation_date': 1220386469,
#    'last_edit_date': 1676406674,
#    'question_id': 40480,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/40480/is-java-pass-by-reference-or-pass-by-value',
#    'title': 'Is Java &quot;pass-by-reference&quot; or &quot;pass-by-value&quot;?'},
#   {'tags': ['javascript', 'jquery', 'redirect'],
#    'owner': {'reputation': 102343,
#     'user_id': 44984,
#     'user_type': 'registered',
#     'accept_rate': 78,
#     'profile_image': 'https://i.stack.imgur.com/7rqob.jpg?s=256&g=1',
#     'display_name': 'venkatachalam',
#     'link': 'https://stackoverflow.com/users/44984/venkatachalam'},
#    'is_answered': True,
#    'view_count': 7682119,
#    'protected_date': 1447333882,
#    'accepted_answer_id': 506004,
#    'answer_count': 58,
#    'score': 7703,
#    'locked_date': 1522910705,
#    'last_activity_date': 1688246665,
#    'creation_date': 1233579256,
#    'last_edit_date': 1517920814,
#    'question_id': 503093,
#    'content_license': 'CC BY-SA 3.0',
#    'link': 'https://stackoverflow.com/questions/503093/how-do-i-redirect-to-another-webpage',
#    'title': 'How do I redirect to another webpage?'},
#   {'tags': ['git', 'git-commit', 'git-rewrite-history', 'git-amend'],
#    'owner': {'reputation': 136084,
#     'user_id': 7473,
#     'user_type': 'registered',
#     'accept_rate': 58,
#     'profile_image': 'https://www.gravatar.com/avatar/9218dd1115bc620ec1ea79fd0368da8e?s=256&d=identicon&r=PG',
#     'display_name': 'Laurie Young',
#     'link': 'https://stackoverflow.com/users/7473/laurie-young'},
#    'is_answered': True,
#    'view_count': 3491576,
#    'protected_date': 1364934455,
#    'accepted_answer_id': 179147,
#    'answer_count': 27,
#    'score': 7650,
#    'locked_date': 1434955517,
#    'last_activity_date': 1643071135,
#    'creation_date': 1223394287,
#    'last_edit_date': 1556792162,
#    'question_id': 179123,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/179123/how-to-modify-existing-unpushed-commit-messages',
#    'title': 'How to modify existing, unpushed commit messages?'},
#   {'tags': ['javascript', 'function', 'variables', 'scope', 'closures'],
#    'owner': {'reputation': 577849,
#     'user_id': 9951,
#     'user_type': 'registered',
#     'accept_rate': 78,
#     'profile_image': 'https://www.gravatar.com/avatar/5bde6be7c103aa64082aa254f66deb51?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Bite code',
#     'link': 'https://stackoverflow.com/users/9951/bite-code'},
#    'is_answered': True,
#    'view_count': 1613844,
#    'protected_date': 1316450131,
#    'accepted_answer_id': 111111,
#    'answer_count': 86,
#    'community_owned_date': 1370514175,
#    'score': 7621,
#    'locked_date': 1497372465,
#    'last_activity_date': 1689527077,
#    'creation_date': 1222006327,
#    'last_edit_date': 1491746117,
#    'question_id': 111102,
#    'content_license': 'CC BY-SA 3.0',
#    'link': 'https://stackoverflow.com/questions/111102/how-do-javascript-closures-work',
#    'title': 'How do JavaScript closures work?'},
#   {'tags': ['git', 'git-checkout', 'git-reset', 'git-revert'],
#    'owner': {'reputation': 76330,
#     'user_id': 111174,
#     'user_type': 'registered',
#     'accept_rate': 63,
#     'profile_image': 'https://www.gravatar.com/avatar/94f2f4d10581cebd4432a10f66fec19f?s=256&d=identicon&r=PG',
#     'display_name': 'Crazy Serb',
#     'link': 'https://stackoverflow.com/users/111174/crazy-serb'},
#    'is_answered': True,
#    'view_count': 10143778,
#    'protected_date': 1506140086,
#    'accepted_answer_id': 4114122,
#    'answer_count': 41,
#    'score': 7611,
#    'locked_date': 1586499211,
#    'last_activity_date': 1688497930,
#    'creation_date': 1289062694,
#    'last_edit_date': 1576501372,
#    'question_id': 4114095,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/4114095/how-do-i-revert-a-git-repository-to-a-previous-commit',
#    'title': 'How do I revert a Git repository to a previous commit?'},
#   {'tags': ['javascript', 'function', 'methods', 'syntax'],
#    'owner': {'reputation': 87749,
#     'user_id': 31569,
#     'user_type': 'registered',
#     'accept_rate': 96,
#     'profile_image': 'https://www.gravatar.com/avatar/2d71a937d0e784ea99153ce46afb9fb1?s=256&d=identicon&r=PG',
#     'display_name': 'Richard Garside',
#     'link': 'https://stackoverflow.com/users/31569/richard-garside'},
#    'is_answered': True,
#    'view_count': 1203941,
#    'protected_date': 1370840753,
#    'accepted_answer_id': 336868,
#    'answer_count': 41,
#    'score': 7578,
#    'last_activity_date': 1686759733,
#    'creation_date': 1228303867,
#    'last_edit_date': 1676360675,
#    'question_id': 336859,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/336859/var-functionname-function-vs-function-functionname',
#    'title': 'var functionName = function() {} vs function functionName() {}'},
#   {'tags': ['java', 'date', 'timezone'],
#    'owner': {'reputation': 193506,
#     'user_id': 342235,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/88e5a9eb011a73ab970ddc8cfb05ff85?s=256&d=identicon&r=PG',
#     'display_name': 'Freewind',
#     'link': 'https://stackoverflow.com/users/342235/freewind'},
#    'is_answered': True,
#    'view_count': 789826,
#    'protected_date': 1433866025,
#    'accepted_answer_id': 6841479,
#    'answer_count': 10,
#    'score': 7502,
#    'last_activity_date': 1684606299,
#    'creation_date': 1311754558,
#    'last_edit_date': 1684606299,
#    'question_id': 6841333,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/6841333/why-is-subtracting-these-two-epoch-milli-times-in-year-1927-giving-a-strange-r',
#    'title': 'Why is subtracting these two epoch-milli Times (in year 1927) giving a strange result?'},
#   {'tags': ['c#', '.net', 'string', 'types', 'alias'],
#    'owner': {'reputation': 25674,
#     'user_id': 571,
#     'user_type': 'registered',
#     'accept_rate': 68,
#     'profile_image': 'https://www.gravatar.com/avatar/c1f0bb6c6d36ab5aba3fdacd1db03bf1?s=256&d=identicon&r=PG',
#     'display_name': 'Lance Fisher',
#     'link': 'https://stackoverflow.com/users/571/lance-fisher'},
#    'is_answered': True,
#    'view_count': 1292341,
#    'protected_date': 1335106652,
#    'accepted_answer_id': 7077,
#    'answer_count': 66,
#    'community_owned_date': 1349347041,
#    'score': 7485,
#    'last_activity_date': 1682717974,
#    'creation_date': 1218352682,
#    'last_edit_date': 1682717974,
#    'question_id': 7074,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/7074/what-is-the-difference-between-string-and-string-in-c',
#    'title': 'What is the difference between String and string in C#?'},
#   {'tags': ['javascript', 'string', 'substring', 'string-matching'],
#    'owner': {'reputation': 18786,
#     'user_id': 131679,
#     'user_type': 'registered',
#     'accept_rate': 63,
#     'profile_image': 'https://www.gravatar.com/avatar/4cb7f78dca34d0e27931f743f3aa1f30?s=256&d=identicon&r=PG',
#     'display_name': 'gramm',
#     'link': 'https://stackoverflow.com/users/131679/gramm'},
#    'is_answered': True,
#    'view_count': 7729853,
#    'protected_date': 1351859467,
#    'accepted_answer_id': 1789952,
#    'answer_count': 3,
#    'community_owned_date': 1388363490,
#    'score': 7407,
#    'locked_date': 1522910801,
#    'last_activity_date': 1666075663,
#    'creation_date': 1259067869,
#    'last_edit_date': 1554297428,
#    'question_id': 1789945,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/1789945/how-to-check-whether-a-string-contains-a-substring-in-javascript',
#    'title': 'How to check whether a string contains a substring in JavaScript?'},
#   {'tags': ['javascript', 'object', 'properties'],
#    'owner': {'reputation': 96102,
#     'user_id': 27929,
#     'user_type': 'registered',
#     'accept_rate': 41,
#     'profile_image': 'https://www.gravatar.com/avatar/8b141abc20af8ebe4667df467a73cc15?s=256&d=identicon&r=PG',
#     'display_name': 'johnstok',
#     'link': 'https://stackoverflow.com/users/27929/johnstok'},
#    'is_answered': True,
#    'view_count': 3095029,
#    'protected_date': 1319135227,
#    'accepted_answer_id': 208106,
#    'answer_count': 38,
#    'score': 7386,
#    'last_activity_date': 1690574966,
#    'creation_date': 1224154665,
#    'last_edit_date': 1661768721,
#    'question_id': 208105,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/208105/how-do-i-remove-a-property-from-a-javascript-object',
#    'title': 'How do I remove a property from a JavaScript object?'},
#   {'tags': ['linux', 'text', 'grep', 'directory', 'find'],
#    'owner': {'reputation': 73619,
#     'user_id': 954986,
#     'user_type': 'registered',
#     'accept_rate': 63,
#     'profile_image': 'https://i.stack.imgur.com/LT4wS.png?s=256&g=1',
#     'display_name': 'Nathan',
#     'link': 'https://stackoverflow.com/users/954986/nathan'},
#    'is_answered': True,
#    'view_count': 10349138,
#    'protected_date': 1438889672,
#    'accepted_answer_id': 16957078,
#    'answer_count': 55,
#    'score': 7300,
#    'last_activity_date': 1690178516,
#    'creation_date': 1370506005,
#    'last_edit_date': 1690178516,
#    'question_id': 16956810,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/16956810/how-to-find-all-files-containing-specific-text-string-on-linux',
#    'title': 'How to find all files containing specific text (string) on Linux?'},
#   {'tags': ['python', 'oop', 'metaclass', 'python-class', 'python-datamodel'],
#    'owner': {'reputation': 577849,
#     'user_id': 9951,
#     'user_type': 'registered',
#     'accept_rate': 78,
#     'profile_image': 'https://www.gravatar.com/avatar/5bde6be7c103aa64082aa254f66deb51?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Bite code',
#     'link': 'https://stackoverflow.com/users/9951/bite-code'},
#    'is_answered': True,
#    'view_count': 1126976,
#    'protected_date': 1350585760,
#    'accepted_answer_id': 100146,
#    'answer_count': 25,
#    'score': 7247,
#    'last_activity_date': 1683518854,
#    'creation_date': 1221804646,
#    'last_edit_date': 1675831759,
#    'question_id': 100003,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/100003/what-are-metaclasses-in-python',
#    'title': 'What are metaclasses in Python?'},
#   {'tags': ['python', 'file', 'file-exists'],
#    'owner': {'reputation': 76925,
#     'user_id': 15616,
#     'user_type': 'registered',
#     'accept_rate': 83,
#     'profile_image': 'https://www.gravatar.com/avatar/1d502f7932af0a41d8ff6ab5d9cf3406?s=256&d=identicon&r=PG',
#     'display_name': 'spence91',
#     'link': 'https://stackoverflow.com/users/15616/spence91'},
#    'is_answered': True,
#    'view_count': 5247925,
#    'protected_date': 1370841219,
#    'answer_count': 40,
#    'score': 6994,
#    'last_activity_date': 1671710916,
#    'creation_date': 1221656100,
#    'last_edit_date': 1616874145,
#    'question_id': 82831,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/82831/how-do-i-check-whether-a-file-exists-without-exceptions',
#    'title': 'How do I check whether a file exists without exceptions?'},
#   {'tags': ['python', 'dictionary', 'merge'],
#    'owner': {'reputation': 121772,
#     'user_id': 3207,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/b1f36e554be0e1ae19f9a74d6ece9107?s=256&d=identicon&r=PG',
#     'display_name': 'Carl Meyer',
#     'link': 'https://stackoverflow.com/users/3207/carl-meyer'},
#    'is_answered': True,
#    'view_count': 3134565,
#    'protected_date': 1392127410,
#    'accepted_answer_id': 26853961,
#    'answer_count': 43,
#    'score': 6772,
#    'last_activity_date': 1677773884,
#    'creation_date': 1220341470,
#    'last_edit_date': 1676185398,
#    'question_id': 38987,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/38987/how-do-i-merge-two-dictionaries-in-a-single-expression-in-python',
#    'title': 'How do I merge two dictionaries in a single expression in Python?'},
#   {'tags': ['javascript', 'ajax', 'asynchronous'],
#    'owner': {'reputation': 794194,
#     'user_id': 218196,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/4P5DY.jpg?s=256&g=1',
#     'display_name': 'Felix Kling',
#     'link': 'https://stackoverflow.com/users/218196/felix-kling'},
#    'is_answered': True,
#    'view_count': 2075269,
#    'protected_date': 1554698603,
#    'accepted_answer_id': 14220323,
#    'answer_count': 42,
#    'score': 6616,
#    'last_activity_date': 1690585441,
#    'creation_date': 1357664774,
#    'last_edit_date': 1657142999,
#    'question_id': 14220321,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/14220321/how-do-i-return-the-response-from-an-asynchronous-call',
#    'title': 'How do I return the response from an asynchronous call?'},
#   {'tags': ['git', 'git-branch', 'branching-and-merging'],
#    'owner': {'reputation': 82173,
#     'user_id': 1103052,
#     'user_type': 'registered',
#     'accept_rate': 88,
#     'profile_image': 'https://www.gravatar.com/avatar/393d9d6acd3ba4ed8ea921dd997d9144?s=256&d=identicon&r=PG',
#     'display_name': 'Mark A. Nicolosi',
#     'link': 'https://stackoverflow.com/users/1103052/mark-a-nicolosi'},
#    'is_answered': True,
#    'view_count': 1658422,
#    'protected_date': 1389659098,
#    'accepted_answer_id': 1628584,
#    'answer_count': 22,
#    'score': 6380,
#    'last_activity_date': 1687287928,
#    'creation_date': 1256612854,
#    'last_edit_date': 1657253401,
#    'question_id': 1628563,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/1628563/move-the-most-recent-commits-to-a-new-branch-with-git',
#    'title': 'Move the most recent commit(s) to a new branch with Git'},
#   {'tags': ['android',
#     'android-layout',
#     'user-interface',
#     'dimension',
#     'units-of-measurement'],
#    'owner': {'reputation': 67313,
#     'user_id': 235885,
#     'user_type': 'registered',
#     'accept_rate': 87,
#     'profile_image': 'https://www.gravatar.com/avatar/a246044d1113994fba38a67ce0205ed9?s=256&d=identicon&r=PG',
#     'display_name': 'capecrawler',
#     'link': 'https://stackoverflow.com/users/235885/capecrawler'},
#    'is_answered': True,
#    'view_count': 1469737,
#    'protected_date': 1303421057,
#    'accepted_answer_id': 2025541,
#    'answer_count': 32,
#    'score': 6330,
#    'last_activity_date': 1664468329,
#    'creation_date': 1262921026,
#    'last_edit_date': 1657518805,
#    'question_id': 2025282,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/2025282/what-is-the-difference-between-px-dip-dp-and-sp',
#    'title': 'What is the difference between px, dip, dp, and sp?'},
#   {'tags': ['http', 'rest', 'post', 'put'],
#    'owner': {'reputation': 74125,
#     'user_id': 19268,
#     'user_type': 'registered',
#     'accept_rate': 88,
#     'profile_image': 'https://www.gravatar.com/avatar/145778821ba747dd30334c0703ebd57f?s=256&d=identicon&r=PG',
#     'display_name': 'alex',
#     'link': 'https://stackoverflow.com/users/19268/alex'},
#    'is_answered': True,
#    'view_count': 3255417,
#    'protected_date': 1306295084,
#    'accepted_answer_id': 630475,
#    'answer_count': 42,
#    'score': 6259,
#    'last_activity_date': 1683979058,
#    'creation_date': 1236695120,
#    'last_edit_date': 1675809577,
#    'question_id': 630453,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/630453/what-is-the-difference-between-post-and-put-in-http',
#    'title': 'What is the difference between POST and PUT in HTTP?'},
#   {'tags': ['javascript', 'file', 'import', 'include'],
#    'owner': {'reputation': 93925,
#     'user_id': 426996,
#     'user_type': 'registered',
#     'accept_rate': 93,
#     'profile_image': 'https://www.gravatar.com/avatar/77f6618dd027eb4c6e4435d206dbd1c3?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Alec Smart',
#     'link': 'https://stackoverflow.com/users/426996/alec-smart'},
#    'is_answered': True,
#    'view_count': 4255168,
#    'protected_date': 1370840821,
#    'accepted_answer_id': 950146,
#    'answer_count': 71,
#    'score': 6234,
#    'last_activity_date': 1683963747,
#    'creation_date': 1244116790,
#    'last_edit_date': 1658706427,
#    'question_id': 950087,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/950087/how-do-i-include-a-javascript-file-in-another-javascript-file',
#    'title': 'How do I include a JavaScript file in another JavaScript file?'},
#   {'tags': ['javascript', 'scope', 'ecmascript-6', 'var', 'let'],
#    'owner': {'reputation': 108098,
#     'user_id': 12983,
#     'user_type': 'registered',
#     'accept_rate': 97,
#     'profile_image': 'https://www.gravatar.com/avatar/b33e8a75c925b361be8ff9568e35b26c?s=256&d=identicon&r=PG',
#     'display_name': 'TM.',
#     'link': 'https://stackoverflow.com/users/12983/tm'},
#    'is_answered': True,
#    'view_count': 2211099,
#    'protected_date': 1465851993,
#    'accepted_answer_id': 11444416,
#    'answer_count': 40,
#    'score': 6150,
#    'last_activity_date': 1688117386,
#    'creation_date': 1239998966,
#    'last_edit_date': 1658411785,
#    'question_id': 762011,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/762011/what-is-the-difference-between-let-and-var',
#    'title': 'What is the difference between &quot;let&quot; and &quot;var&quot;?'},
#   {'tags': ['git', 'version-control'],
#    'owner': {'reputation': 342784,
#     'user_id': 4883,
#     'user_type': 'registered',
#     'accept_rate': 82,
#     'profile_image': 'https://www.gravatar.com/avatar/a92525f049e20db8f4ce3d62f3f0bb2b?s=256&d=identicon&r=PG',
#     'display_name': 'readonly',
#     'link': 'https://stackoverflow.com/users/4883/readonly'},
#    'is_answered': True,
#    'view_count': 3914361,
#    'protected_date': 1401530271,
#    'accepted_answer_id': 52719,
#    'answer_count': 41,
#    'score': 6145,
#    'last_activity_date': 1677659340,
#    'creation_date': 1220988839,
#    'last_edit_date': 1658911366,
#    'question_id': 52704,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/52704/how-do-i-discard-unstaged-changes-in-git',
#    'title': 'How do I discard unstaged changes in Git?'},
#   {'tags': ['bash', 'directory'],
#    'owner': {'reputation': 74325,
#     'user_id': 2908,
#     'user_type': 'registered',
#     'accept_rate': 97,
#     'profile_image': 'https://www.gravatar.com/avatar/30e3f436d5fb8e941126a0c2c2868f84?s=256&d=identicon&r=PG',
#     'display_name': 'Jiaaro',
#     'link': 'https://stackoverflow.com/users/2908/jiaaro'},
#    'is_answered': True,
#    'view_count': 2457540,
#    'protected_date': 1370840795,
#    'accepted_answer_id': 246128,
#    'answer_count': 75,
#    'community_owned_date': 1300910776,
#    'score': 6124,
#    'last_activity_date': 1688315352,
#    'creation_date': 1221251996,
#    'last_edit_date': 1658706687,
#    'question_id': 59895,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/59895/how-do-i-get-the-directory-where-a-bash-script-is-located-from-within-the-script',
#    'title': 'How do I get the directory where a Bash script is located from within the script itself?'},
#   {'tags': ['css', 'cross-browser', 'highlight', 'textselection'],
#    'owner': {'user_type': 'does_not_exist', 'display_name': 'anon'},
#    'is_answered': True,
#    'view_count': 2657389,
#    'protected_date': 1335386570,
#    'answer_count': 45,
#    'score': 6039,
#    'last_activity_date': 1669830358,
#    'creation_date': 1241555358,
#    'last_edit_date': 1658706634,
#    'question_id': 826782,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/826782/how-to-disable-text-selection-highlighting',
#    'title': 'How to disable text selection highlighting'},
#   {'tags': ['git', 'url', 'git-remote'],
#    'owner': {'reputation': 577849,
#     'user_id': 9951,
#     'user_type': 'registered',
#     'accept_rate': 78,
#     'profile_image': 'https://www.gravatar.com/avatar/5bde6be7c103aa64082aa254f66deb51?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Bite code',
#     'link': 'https://stackoverflow.com/users/9951/bite-code'},
#    'is_answered': True,
#    'view_count': 3561602,
#    'protected_date': 1416332507,
#    'accepted_answer_id': 2432799,
#    'answer_count': 34,
#    'score': 6011,
#    'last_activity_date': 1674482258,
#    'creation_date': 1268398127,
#    'last_edit_date': 1661369384,
#    'question_id': 2432764,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/2432764/how-do-i-change-the-uri-url-for-a-remote-git-repository',
#    'title': 'How do I change the URI (URL) for a remote Git repository?'},
#   {'tags': ['python', 'shell', 'terminal', 'subprocess', 'command'],
#    'owner': {'reputation': 61869,
#     'user_id': 17085,
#     'user_type': 'registered',
#     'accept_rate': 89,
#     'profile_image': 'https://www.gravatar.com/avatar/d386a6f2f3dda7bcf7f1e11c2171946b?s=256&d=identicon&r=PG',
#     'display_name': 'freshWoWer',
#     'link': 'https://stackoverflow.com/users/17085/freshwower'},
#    'is_answered': True,
#    'view_count': 4425886,
#    'protected_date': 1366143800,
#    'accepted_answer_id': 89243,
#    'answer_count': 66,
#    'score': 6009,
#    'last_activity_date': 1690205934,
#    'creation_date': 1221701730,
#    'last_edit_date': 1671066365,
#    'question_id': 89228,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/89228/how-do-i-execute-a-program-or-call-a-system-command',
#    'title': 'How do I execute a program or call a system command?'},
#   {'tags': ['javascript',
#     'operators',
#     'equality',
#     'equality-operator',
#     'identity-operator'],
#    'owner': {'reputation': 57397,
#     'user_id': 44990,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/3a15a9709950fe8e7e5a2e1ef184f5d5?s=256&d=identicon&r=PG',
#     'display_name': 'bcasp',
#     'link': 'https://stackoverflow.com/users/44990/bcasp'},
#    'is_answered': True,
#    'view_count': 2104108,
#    'protected_date': 1349355201,
#    'accepted_answer_id': 359509,
#    'answer_count': 48,
#    'score': 5649,
#    'locked_date': 1531965274,
#    'last_activity_date': 1683401888,
#    'creation_date': 1229005189,
#    'last_edit_date': 1490199217,
#    'question_id': 359494,
#    'content_license': 'CC BY-SA 3.0',
#    'link': 'https://stackoverflow.com/questions/359494/which-equals-operator-vs-should-be-used-in-javascript-comparisons',
#    'title': 'Which equals operator (== vs ===) should be used in JavaScript comparisons?'},
#   {'tags': ['http', 'url', 'browser'],
#    'owner': {'reputation': 72647,
#     'user_id': 2172,
#     'user_type': 'registered',
#     'accept_rate': 86,
#     'profile_image': 'https://www.gravatar.com/avatar/d45a34439ae17a079045a23df5131b91?s=256&d=identicon&r=PG',
#     'display_name': 'Sander Versluys',
#     'link': 'https://stackoverflow.com/users/2172/sander-versluys'},
#    'is_answered': True,
#    'view_count': 1623008,
#    'protected_date': 1613704472,
#    'accepted_answer_id': 417184,
#    'answer_count': 18,
#    'score': 5634,
#    'last_activity_date': 1685075826,
#    'creation_date': 1231258470,
#    'last_edit_date': 1676828776,
#    'question_id': 417142,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/417142/what-is-the-maximum-length-of-a-url-in-different-browsers',
#    'title': 'What is the maximum length of a URL in different browsers?'},
#   {'tags': ['git', 'version-control', 'git-checkout'],
#    'owner': {'reputation': 66493,
#     'user_id': 3410,
#     'user_type': 'registered',
#     'accept_rate': 90,
#     'profile_image': 'https://i.stack.imgur.com/rOJJg.png?s=256&g=1',
#     'display_name': 'Hates_',
#     'link': 'https://stackoverflow.com/users/3410/hates'},
#    'is_answered': True,
#    'view_count': 2867441,
#    'protected_date': 1512475709,
#    'accepted_answer_id': 215731,
#    'answer_count': 36,
#    'score': 5629,
#    'last_activity_date': 1684916613,
#    'creation_date': 1224372842,
#    'last_edit_date': 1657253872,
#    'question_id': 215718,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/215718/how-do-i-reset-or-revert-a-file-to-a-specific-revision',
#    'title': 'How do I reset or revert a file to a specific revision?'},
#   {'tags': ['javascript', 'arrays', 'loops', 'foreach', 'iteration'],
#    'owner': {'reputation': 58239,
#     'user_id': 1140876,
#     'user_type': 'registered',
#     'accept_rate': 87,
#     'profile_image': 'https://www.gravatar.com/avatar/35c44645d7729e6828f494f5e20d5909?s=256&d=identicon&r=PG',
#     'display_name': 'Dante1986',
#     'link': 'https://stackoverflow.com/users/1140876/dante1986'},
#    'is_answered': True,
#    'view_count': 5207420,
#    'protected_date': 1396537395,
#    'accepted_answer_id': 9329476,
#    'answer_count': 41,
#    'score': 5612,
#    'last_activity_date': 1685012875,
#    'creation_date': 1329486708,
#    'last_edit_date': 1674303372,
#    'question_id': 9329446,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/9329446/loop-for-each-over-an-array-in-javascript',
#    'title': 'Loop (for each) over an array in JavaScript'},
#   {'tags': ['git', 'repository', 'git-branch', 'git-push', 'git-remote'],
#    'owner': {'reputation': 57581,
#     'user_id': 222187,
#     'user_type': 'registered',
#     'accept_rate': 80,
#     'profile_image': 'https://www.gravatar.com/avatar/3aa8157fa52c32beb1fbb37baa64023f?s=256&d=identicon&r=PG',
#     'display_name': 'Roni Yaniv',
#     'link': 'https://stackoverflow.com/users/222187/roni-yaniv'},
#    'is_answered': True,
#    'view_count': 5603550,
#    'protected_date': 1389658809,
#    'accepted_answer_id': 6232535,
#    'answer_count': 18,
#    'score': 5543,
#    'last_activity_date': 1675227844,
#    'creation_date': 1272977914,
#    'last_edit_date': 1658714620,
#    'question_id': 2765421,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/2765421/how-do-i-push-a-new-local-branch-to-a-remote-git-repository-and-track-it-too',
#    'title': 'How do I push a new local branch to a remote Git repository and track it too?'},
#   {'tags': ['python', 'exception', 'path', 'directory', 'operating-system'],
#    'owner': {'reputation': 102790,
#     'user_id': 13055,
#     'user_type': 'registered',
#     'accept_rate': 68,
#     'profile_image': 'https://www.gravatar.com/avatar/ab82fd8b5ffe4d09c2bb5f9c14d34b09?s=256&d=identicon&r=PG',
#     'display_name': 'Parand',
#     'link': 'https://stackoverflow.com/users/13055/parand'},
#    'is_answered': True,
#    'view_count': 3567142,
#    'protected_date': 1392127892,
#    'accepted_answer_id': 273227,
#    'answer_count': 27,
#    'score': 5542,
#    'last_activity_date': 1682873974,
#    'creation_date': 1226084205,
#    'last_edit_date': 1682319558,
#    'question_id': 273192,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/273192/how-do-i-create-a-directory-and-any-missing-parent-directories',
#    'title': 'How do I create a directory, and any missing parent directories?'},
#   {'tags': ['forms',
#     'http',
#     'security',
#     'authentication',
#     'language-agnostic'],
#    'owner': {'reputation': 41932,
#     'user_id': 136,
#     'user_type': 'registered',
#     'accept_rate': 73,
#     'profile_image': 'https://www.gravatar.com/avatar/901fdd0c1bd863f1c3b72cddc5a66039?s=256&d=identicon&r=PG',
#     'display_name': 'Michiel de Mare',
#     'link': 'https://stackoverflow.com/users/136/michiel-de-mare'},
#    'is_answered': True,
#    'view_count': 674343,
#    'closed_date': 1470899988,
#    'accepted_answer_id': 477578,
#    'answer_count': 11,
#    'community_owned_date': 1222821554,
#    'score': 5518,
#    'locked_date': 1636658577,
#    'last_activity_date': 1651059647,
#    'creation_date': 1217706710,
#    'last_edit_date': 1636659316,
#    'question_id': 549,
#    'link': 'https://stackoverflow.com/questions/549/the-definitive-guide-to-form-based-website-authentication',
#    'closed_reason': 'Needs more focus',
#    'title': 'The definitive guide to form-based website authentication'},
#   {'tags': ['git', 'undo'],
#    'owner': {'reputation': 153889,
#     'user_id': 128983,
#     'user_type': 'registered',
#     'accept_rate': 55,
#     'profile_image': 'https://www.gravatar.com/avatar/da7a3c3efd21c067831e68c9c9c55636?s=256&d=identicon&r=PG',
#     'display_name': 'hap497',
#     'link': 'https://stackoverflow.com/users/128983/hap497'},
#    'is_answered': True,
#    'view_count': 5797172,
#    'protected_date': 1599136757,
#    'accepted_answer_id': 1628334,
#    'answer_count': 26,
#    'score': 5510,
#    'last_activity_date': 1689092151,
#    'creation_date': 1256603240,
#    'last_edit_date': 1659477907,
#    'question_id': 1628088,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/1628088/reset-local-repository-branch-to-be-just-like-remote-repository-head',
#    'title': 'Reset local repository branch to be just like remote repository HEAD'},
#   {'tags': ['javascript', 'html', 'regex', 'email-validation'],
#    'owner': {'reputation': 31139,
#     'user_id': 72,
#     'user_type': 'registered',
# ...
#    'owner': {'reputation': 40360,
#     'user_id': 301032,
#     'user_type': 'registered',
#     'accept_rate': 62,
#     'profile_image': 'https://www.gravatar.com/avatar/06b3210955831102992eb6b1d0a0e612?s=256&d=identicon&r=PG',
#     'display_name': 'richzilla',
#     'link': 'https://stackoverflow.com/users/301032/richzilla'},
#    'is_answered': True,
#    'view_count': 2616868,
#    'protected_date': 1441940942,
#    'accepted_answer_id': 5844692,
#    'answer_count': 19,
#    'score': 2115,
#    'last_activity_date': 1676198379,
#    'creation_date': 1304198457,
#    'last_edit_date': 1676198379,
#    'question_id': 5844672,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/5844672/delete-an-element-from-a-dictionary',
#    'title': 'Delete an element from a dictionary'},
#   {'tags': ['docker', 'ip-address'],
#    'owner': {'reputation': 21638,
#     'user_id': 1131518,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/e61e0c6b9dd794e702df9caf5354060d?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Murali Allada',
#     'link': 'https://stackoverflow.com/users/1131518/murali-allada'},
#    'is_answered': True,
#    'view_count': 2285780,
#    'protected_date': 1525878929,
#    'accepted_answer_id': 20686101,
#    'answer_count': 56,
#    'score': 2113,
#    'last_activity_date': 1686748290,
#    'creation_date': 1371507022,
#    'last_edit_date': 1617888756,
#    'question_id': 17157721,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/17157721/how-to-get-a-docker-containers-ip-address-from-the-host',
#    'title': 'How to get a Docker container&#39;s IP address from the host'},
#   {'tags': ['linux', 'unix', 'grep'],
#    'owner': {'reputation': 21267,
#     'user_id': 240663,
#     'user_type': 'unregistered',
#     'accept_rate': 60,
#     'profile_image': 'https://www.gravatar.com/avatar/1c1079a7b3e0185c015f1c7d5e5e6bc4?s=256&d=identicon&r=PG',
#     'display_name': 'wpiri',
#     'link': 'https://stackoverflow.com/users/240663/wpiri'},
#    'is_answered': True,
#    'view_count': 2137356,
#    'protected_date': 1405551481,
#    'accepted_answer_id': 1987928,
#    'answer_count': 27,
#    'score': 2111,
#    'last_activity_date': 1690269630,
#    'creation_date': 1262322612,
#    'last_edit_date': 1637267058,
#    'question_id': 1987926,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/1987926/how-do-i-recursively-grep-all-directories-and-subdirectories',
#    'title': 'How do I recursively grep all directories and subdirectories?'},
#   {'tags': ['bash', 'shell', 'for-loop', 'syntax'],
#    'owner': {'reputation': 21957,
#     'user_id': 24923,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/cf3fb8d74900ac72aa68fee46c4fb506?s=256&d=identicon&r=PG',
#     'display_name': 'eschercycle',
#     'link': 'https://stackoverflow.com/users/24923/eschercycle'},
#    'is_answered': True,
#    'view_count': 1675711,
#    'protected_date': 1533070413,
#    'accepted_answer_id': 169517,
#    'answer_count': 20,
#    'score': 2109,
#    'last_activity_date': 1689504768,
#    'creation_date': 1223084323,
#    'last_edit_date': 1689504768,
#    'question_id': 169511,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/169511/how-do-i-iterate-over-a-range-of-numbers-defined-by-variables-in-bash',
#    'title': 'How do I iterate over a range of numbers defined by variables in Bash?'},
#   {'tags': ['javascript', 'arrays', 'deep-copy', 'pass-by-value'],
#    'owner': {'reputation': 21347,
#     'user_id': 944555,
#     'user_type': 'registered',
#     'accept_rate': 44,
#     'profile_image': 'https://www.gravatar.com/avatar/8de6ad7e2c5242662fe32fabfec90545?s=256&d=identicon&r=PG',
#     'display_name': 'Dan',
#     'link': 'https://stackoverflow.com/users/944555/dan'},
#    'is_answered': True,
#    'view_count': 1232755,
#    'protected_date': 1406723089,
#    'accepted_answer_id': 7486130,
#    'answer_count': 40,
#    'score': 2106,
#    'last_activity_date': 1690534656,
#    'creation_date': 1316525888,
#    'last_edit_date': 1690534656,
#    'question_id': 7486085,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/7486085/copy-array-by-value',
#    'title': 'Copy array by value'},
#   {'tags': ['javascript', 'ajax', 'google-chrome'],
#    'owner': {'reputation': 76281,
#     'user_id': 1785,
#     'user_type': 'registered',
#     'accept_rate': 51,
#     'profile_image': 'https://i.stack.imgur.com/5ZS3T.jpg?s=256&g=1',
#     'display_name': 'Landon Kuhn',
#     'link': 'https://stackoverflow.com/users/1785/landon-kuhn'},
#    'is_answered': True,
#    'view_count': 3260437,
#    'protected_date': 1444036900,
#    'accepted_answer_id': 3177718,
#    'answer_count': 36,
#    'score': 2105,
#    'last_activity_date': 1690031042,
#    'creation_date': 1277305221,
#    'last_edit_date': 1557936704,
#    'question_id': 3102819,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/3102819/disable-same-origin-policy-in-chrome',
#    'title': 'Disable same origin policy in Chrome'},
#   {'tags': ['git', 'git-clone', 'git-tag'],
#    'owner': {'reputation': 35691,
#     'user_id': 64895,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://www.gravatar.com/avatar/340c167b065daea534a020efa1fb6649?s=256&d=identicon&r=PG',
#     'display_name': 'Jack BeNimble',
#     'link': 'https://stackoverflow.com/users/64895/jack-benimble'},
#    'is_answered': True,
#    'view_count': 1600716,
#    'protected_date': 1522884006,
#    'accepted_answer_id': 792027,
#    'answer_count': 16,
#    'score': 2103,
#    'last_activity_date': 1630640838,
#    'creation_date': 1240794912,
#    'last_edit_date': 1485716729,
#    'question_id': 791959,
#    'content_license': 'CC BY-SA 3.0',
#    'link': 'https://stackoverflow.com/questions/791959/download-a-specific-tag-with-git',
#    'title': 'Download a specific tag with Git'},
#   {'tags': ['node.js', 'linux', 'npm', 'node-modules', 'npm-update'],
#    'owner': {'reputation': 21241,
#     'user_id': 783783,
#     'user_type': 'unregistered',
#     'profile_image': 'https://www.gravatar.com/avatar/edb4f5a60f04e78366d548a67abd6894?s=256&d=identicon&r=PG',
#     'display_name': 'Dail',
#     'link': 'https://stackoverflow.com/users/783783/dail'},
#    'is_answered': True,
#    'view_count': 2127860,
#    'protected_date': 1523958729,
#    'answer_count': 65,
#    'score': 2102,
#    'last_activity_date': 1687253017,
#    'creation_date': 1307197713,
#    'last_edit_date': 1648186615,
#    'question_id': 6237295,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/6237295/how-can-i-update-nodejs-and-npm-to-their-latest-versions',
#    'title': 'How can I update NodeJS and NPM to their latest versions?'},
#   {'tags': ['git', 'git-branch'],
#    'owner': {'reputation': 23872,
#     'user_id': 133986,
#     'user_type': 'registered',
#     'accept_rate': 85,
#     'profile_image': 'https://www.gravatar.com/avatar/81ffdc7467e20214e5cdce679a307eaf?s=256&d=identicon&r=PG',
#     'display_name': 'Mailo Světel',
#     'link': 'https://stackoverflow.com/users/133986/mailo-sv%c4%9btel'},
#    'is_answered': True,
#    'view_count': 943398,
#    'accepted_answer_id': 28464339,
#    'answer_count': 48,
#    'score': 2100,
#    'last_activity_date': 1677762839,
#    'creation_date': 1318340255,
#    'last_edit_date': 1534167527,
#    'question_id': 7726949,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/7726949/remove-tracking-branches-no-longer-on-remote',
#    'title': 'Remove tracking branches no longer on remote'},
#   {'tags': ['python', 'string', 'zero-padding'],
#    'owner': {'user_type': 'does_not_exist', 'display_name': 'Faisal'},
#    'is_answered': True,
#    'view_count': 1455575,
#    'protected_date': 1472565382,
#    'accepted_answer_id': 339013,
#    'answer_count': 19,
#    'score': 2097,
#    'last_activity_date': 1670285734,
#    'creation_date': 1228343991,
#    'last_edit_date': 1655081148,
#    'question_id': 339007,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/339007/how-do-i-pad-a-string-with-zeroes',
#    'title': 'How do I pad a string with zeroes?'},
#   {'tags': ['c++', 'c', 'linkage', 'name-mangling', 'extern-c'],
#    'owner': {'reputation': 22514,
#     'user_id': 125848,
#     'user_type': 'registered',
#     'accept_rate': 82,
#     'profile_image': 'https://www.gravatar.com/avatar/672a6697b3b92e7e68491e41e5a47659?s=256&d=identicon&r=PG',
#     'display_name': 'Litherum',
#     'link': 'https://stackoverflow.com/users/125848/litherum'},
#    'is_answered': True,
#    'view_count': 1164158,
#    'protected_date': 1489045302,
#    'accepted_answer_id': 1041880,
#    'answer_count': 18,
#    'score': 2096,
#    'last_activity_date': 1686320934,
#    'creation_date': 1245895807,
#    'last_edit_date': 1521102908,
#    'question_id': 1041866,
#    'content_license': 'CC BY-SA 3.0',
#    'link': 'https://stackoverflow.com/questions/1041866/what-is-the-effect-of-extern-c-in-c',
#    'title': 'What is the effect of extern &quot;C&quot; in C++?'},
#   {'tags': ['javascript', 'jquery', 'file-upload'],
#    'owner': {'reputation': 21173,
#     'user_id': 518838,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://www.gravatar.com/avatar/dd9dddfe9c9d8a86ff231e94c2a26aca?s=256&d=identicon&r=PG',
#     'display_name': 'Simbian',
#     'link': 'https://stackoverflow.com/users/518838/simbian'},
#    'is_answered': True,
#    'view_count': 1718407,
#    'protected_date': 1360593875,
#    'accepted_answer_id': 4459419,
#    'answer_count': 30,
#    'score': 2095,
#    'last_activity_date': 1690532087,
#    'creation_date': 1292493092,
#    'last_edit_date': 1315306165,
#    'question_id': 4459379,
#    'content_license': 'CC BY-SA 3.0',
#    'link': 'https://stackoverflow.com/questions/4459379/preview-an-image-before-it-is-uploaded',
#    'title': 'Preview an image before it is uploaded'},
#   {'tags': ['javascript', 'arrays', 'javascript-objects', 'array-of-dict'],
#    'owner': {'reputation': 22806,
#     'user_id': 614566,
#     'user_type': 'registered',
#     'accept_rate': 91,
#     'profile_image': 'https://www.gravatar.com/avatar/8ee1643d8422a3af4c8dc625166d373a?s=256&d=identicon&r=PG',
#     'display_name': 'thugsb',
#     'link': 'https://stackoverflow.com/users/614566/thugsb'},
#    'is_answered': True,
#    'view_count': 2377406,
#    'protected_date': 1477299038,
#    'accepted_answer_id': 35398031,
#    'answer_count': 36,
#    'score': 2094,
#    'last_activity_date': 1676497816,
#    'creation_date': 1315582949,
#    'last_edit_date': 1676497816,
#    'question_id': 7364150,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/7364150/find-object-by-id-in-an-array-of-javascript-objects',
#    'title': 'Find object by id in an array of JavaScript objects'},
#   {'tags': ['java',
#     'methods',
#     'parameters',
#     'overloading',
#     'default-parameters'],
#    'owner': {'reputation': 25052,
#     'user_id': 99317,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bc2e00dbe90b975153a8b9869ed91193?s=256&d=identicon&r=PG',
#     'display_name': 'gnavi',
#     'link': 'https://stackoverflow.com/users/99317/gnavi'},
#    'is_answered': True,
#    'view_count': 1913822,
#    'protected_date': 1365591866,
#    'accepted_answer_id': 997529,
#    'answer_count': 28,
#    'score': 2092,
#    'last_activity_date': 1676643130,
#    'creation_date': 1245089068,
#    'last_edit_date': 1557306081,
#    'question_id': 997482,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/997482/does-java-support-default-parameter-values',
#    'title': 'Does Java support default parameter values?'},
#   {'tags': ['c++', 'string', 'type-conversion', 'integer'],
#    'owner': {'reputation': 24480,
#     'user_id': 490246,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://www.gravatar.com/avatar/71665274b8587ff501a201efb7c8af73?s=256&d=identicon&r=PG',
#     'display_name': 'Nemo',
#     'link': 'https://stackoverflow.com/users/490246/nemo'},
#    'is_answered': True,
#    'view_count': 4556065,
#    'protected_date': 1392620105,
#    'accepted_answer_id': 5591169,
#    'answer_count': 31,
#    'score': 2091,
#    'last_activity_date': 1688091867,
#    'creation_date': 1302236381,
#    'last_edit_date': 1688091867,
#    'question_id': 5590381,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/5590381/how-to-convert-int-to-string-in-c',
#    'title': 'How to convert int to string in C++?'},
#   {'tags': ['git', 'merge', 'git-branch'],
#    'owner': {'reputation': 22595,
#     'user_id': 220274,
#     'user_type': 'registered',
#     'accept_rate': 56,
#     'profile_image': 'https://www.gravatar.com/avatar/90cae8a3bd6ae69b80748c87932ef5ec?s=256&d=identicon&r=PG',
#     'display_name': 'Jason',
#     'link': 'https://stackoverflow.com/users/220274/jason'},
#    'is_answered': True,
#    'view_count': 875545,
#    'protected_date': 1389658817,
#    'closed_date': 1580453397,
#    'accepted_answer_id': 2862938,
#    'answer_count': 5,
#    'score': 2090,
#    'last_activity_date': 1666254009,
#    'creation_date': 1274238389,
#    'last_edit_date': 1534702110,
#    'question_id': 2862590,
#    'link': 'https://stackoverflow.com/questions/2862590/how-to-replace-master-branch-in-git-entirely-from-another-branch',
#    'closed_reason': 'Duplicate',
#    'title': 'How to replace master branch in Git, entirely, from another branch?'},
#   {'tags': ['syntax', 'comments', 'markdown'],
#    'owner': {'reputation': 26368,
#     'user_id': 248914,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://www.gravatar.com/avatar/e878ba29d544e2c1eaf24b4bf9c35157?s=256&d=identicon&r=PG',
#     'display_name': 'Betamos',
#     'link': 'https://stackoverflow.com/users/248914/betamos'},
#    'is_answered': True,
#    'view_count': 956392,
#    'protected_date': 1491157651,
#    'accepted_answer_id': 20885980,
#    'answer_count': 22,
#    'score': 2089,
#    'last_activity_date': 1672115261,
#    'creation_date': 1296173891,
#    'last_edit_date': 1608537245,
#    'question_id': 4823468,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/4823468/comments-in-markdown',
#    'title': 'Comments in Markdown'},
#   {'tags': ['android', 'python', 'jython', 'ase', 'android-scripting'],
#    'owner': {'reputation': 577849,
#     'user_id': 9951,
#     'user_type': 'registered',
#     'accept_rate': 78,
#     'profile_image': 'https://www.gravatar.com/avatar/5bde6be7c103aa64082aa254f66deb51?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Bite code',
#     'link': 'https://stackoverflow.com/users/9951/bite-code'},
#    'is_answered': True,
#    'view_count': 752504,
#    'protected_date': 1341892047,
#    'accepted_answer_id': 8189603,
#    'answer_count': 23,
#    'score': 2085,
#    'locked_date': 1554911907,
#    'last_activity_date': 1685551187,
#    'creation_date': 1221830472,
#    'last_edit_date': 1541704154,
#    'question_id': 101754,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/101754/is-there-a-way-to-run-python-on-android',
#    'title': 'Is there a way to run Python on Android?'},
#   {'tags': ['javascript', 'arrays', 'list', 'variables'],
#    'owner': {'reputation': 37578,
#     'user_id': 3362,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://www.gravatar.com/avatar/0cf4f188cb71c6a0dd0b28ff081ceb89?s=256&d=identicon&r=PG',
#     'display_name': 'Andy McCluggage',
#     'link': 'https://stackoverflow.com/users/3362/andy-mccluggage'},
#    'is_answered': True,
#    'view_count': 1198273,
#    'protected_date': 1395830832,
#    'accepted_answer_id': 26633883,
#    'answer_count': 25,
#    'score': 2084,
#    'last_activity_date': 1678410508,
#    'creation_date': 1240218179,
#    'last_edit_date': 1649595544,
#    'question_id': 767486,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/767486/how-do-i-check-if-a-variable-is-an-array-in-javascript',
#    'title': 'How do I check if a variable is an array in JavaScript?'}]}

# %%
date_string = "2023-08-04"
date = datetime.datetime.strptime(date_string, "%Y-%m-%d")
timestamp = datetime.datetime.timestamp(date)

for i in questions.get('items'):
    if 'python' in i.get('tags') and i.get('score') >= 5 and i.get('creation_date') >= timestamp:
        print(i)
        
# There are no questions under this requirements

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answers = SITE.fetch('answers')

for answer in answers.get('items'):
    if answer.get('answer_id') == 6784 or answer.get('answer_id') == 6473:
        print(answer)
